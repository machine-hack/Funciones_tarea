# %% [markdown]
# 1.1.2.1 Mensaje escriba una funcion llamada display_message() que imprima en la pantalla un mensaje que indique los temas que se han visto hasta el momento.

# %%
def display_message():
  """Mostrar los temas vistos hasta el momento en colab"""
  print("los temas vistos son: funciones, definicion de una funcion y pasar informacion a la funcion")
#Ya estamos fuera de la funcion y ya podemos imprimir
display_message()
# Out:
# los temas vistos son: funciones, definicion de una funcion y pasar informacion a la funcion

# %% [markdown]
# 1.1.2.2 Libro favorito escriba una funcion que se llame libro_favorito() que acepte el parametro llamado titulo y que despliegue en la terminal tu libro favorito es (nombre del libro)

# %%
def libro_favorito(titulo):
  """Nombre de mi libro favorito"""
  print("Mi libro favorito es: " +titulo.title()+", excelente libro, lo recomiendo")
libro_favorito("Salem´s Lot")
# Out:
# Mi libro favorito es: Salem´S Lot, excelente libro, lo recomiendo

# %% [markdown]
# 1.3.1 Playera: Escriba una funcion llamada hacerPlayer() que acepte como argumento el tamaño y un texto que aparecera cerigrafeado en la playera. La funcion debera imprimir en la terminal algo parecido a lo siguiente.  La playera es talla grande y el texto cerigrafeado es "hola amigos".
# para verificar el correcto funcionamiento de la funcion, genere un programa que lo invoque

# %%
def hacerPlayera(talla, texto):
    print("\nLa talla de la playera es "+talla.title())
    print("El texto es el siguiente "+texto.title())

# %%
hacerPlayera("Grande", "Hola amigos")
# Out:
# La talla de la playera es Grande
# El texto es el siguiente Hola Amigos

# %% [markdown]
# 1.3.2 Playeras grandes: modifica la funcion hacerPlayera() de tal manera que las playeras grandes sean predeterminadas

# %%
def hacerPlayera (talla,texto="Hola mundo"):
    print("\nLa talla de la playera es "+talla.title())
    print("El texto es el siguiente "+texto.title())
hacerPlayera(talla="Grande")
# Out:
# La talla de la playera es Grande
# El texto es el siguiente Hola Mundo

# %% [markdown]
# 1.3.3 paises y ciudades: Escriba una funcion llamada descripcionCiudad() que acepte como argumentos el nombre de una ciudad y el nombre de un país como argumentos y que imprima en la terminal un texto como: Xalapa está en México, Río de Janeiro está en Brazil, París está en Fracia. Ponga como valor predeterminado "México" a la variable país, y llame a la función tres veces donde por lo menos una ciudad no pertenezca al país México.

# %%
def descripcionCiudad(ciudad,país="México"):
  print("El país en el que estas se llama "+país.title()+ " y la ciudad "+ciudad.title())
descripcionCiudad(ciudad="puebla")
# Out:
# El país en el que estas se llama México y la ciudad Puebla

# %%
descripcionCiudad(ciudad="Liverpool")
# Out:
# El país en el que estas se llama México y la ciudad Liverpool

# %% [markdown]
# 1.6 Ejercicios
# 1)Hacer un modulo con las funciones basicas para una calculadora, suma, resta, producto, y division si el denominador es igual a cero debe de volver a leer el valor del denominador hasta que sea distinto de cero (se recomienda usar el ciclo while y el condicional if)
# 2) Hacer una funcion que el usuario introduzca un número y la funcion debe de desplegar un triangulo de sumas, como ejemplo si el usuario manda a la funcion el número 4 debera imprimir el siguiente arreglo
# +
# ++
# +++
# ++++

# %%
def suma ():
  a=float(input("Ingresa el valor de a: "))
  b=float(input("ingrese el valor de b: "))
  sum=a+b
  return sum
print("El valor de la suma es: "+str(suma()))
def resta():
  a=float(input("Ingrese el valor de a: "))
  b=float(input("Ingrese el valor de b: "))
  rest=a-b
  return rest
print ("El valor de la resta es: "+str(resta()))
def multiplicacion ():
  a=float(input("Ingrese el valor de a: "))
  b=float(input("Ingrese el valor de b: "))
  mult=a*b
  return mult
print("El valor de la multipilcacion es: "+str(multiplicacion()))
def div ():
  a=float(input("Ingrese el valor de a: "))
  b=float(input("Ingrese el valor de b: "))
  while (b>0):
    division=a/b
    return division
  else:
    print ("Ingrese un valor mayor a 0")
    b=float(input("Ingrese el valor de b que se mayor que cero: "))
    div=a/b
    return div
print("El valor de la multipilcacion es: "+str(div()))
# Out:
# Ingresa el valor de a: 3
# ingrese el valor de b: 3
# El valor de la suma es: 6.0
# Ingrese el valor de a: 5
# Ingrese el valor de b: 6
# El valor de la resta es: -1.0
# Ingrese el valor de a: 4
# Ingrese el valor de b: 6
# El valor de la multipilcacion es: 24.0
# Ingrese el valor de a: 6
# Ingrese el valor de b: 0
# Ingrese un valor mayor a 0
# Ingrese el valor de b que se mayor que cero: 8
# El valor de la multipilcacion es: 0.75

# %%
a=int(input("Ingrese el numero "))
for fila in range(1, a+1):
  for columna in range (1, fila +1 ):
    print(columna, end="")
  print("")
# Out:
# Ingrese el numero 4
# 1
# 12
# 123
# 1234
